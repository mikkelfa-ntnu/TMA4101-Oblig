# %%
import matplotlib.pyplot as plt
import numpy as np

R=3300
C=100e-6
V=10

x=np.linspace(0,3,1000)

def f(t):
    return (1-np.exp(-t/(R*C)))*V

plt.plot(x,f(x))
plt.xlabel("Tid [t]")
plt.ylabel("Spenning [V]")
plt.show()
